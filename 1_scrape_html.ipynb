# %% [markdown]
# # Scrape HTML of trip descriptions
# In this notebook we use `requests` to get the URLs to all accounts of LSD trips, and scrape the raw HTML for each.

# %%
import requests

# %% [markdown]
# Firstly we will scrape HTML from the index page of all LSD trip accounts

# %%
# Website top level URL
BASE_URL = 'https://www.erowid.org'
SAVE_PATH = Path('./artefacts')
# Path to index of accounts
EXPERIENCE_INDEX_URL = BASE_URL + '/experiences/exp.cgi'
LSD_INDEX_URL = BASE_URL + '/experiences/subs/exp_LSD.shtml'
LSD_GENERAL_INDEX_URL = BASE_URL + '/experiences/subs/exp_LSD_General.shtml'

# %% [markdown]
# At time of analysis there are 657 general LSD experience reports. By default, only 100 are listed on the page at a time. To view all at on a single page, we need to generate a different URL using the general experience URL and Erowid's param API.
#
# - `S` specifies the drug ('2' for LSD)
# - `C` specifies the type of experience ('1' for general)
#
# We will define a helper function to achieve this task with any URL, as well as to save to file and avoid re-scraping pages.

# %%
def get_html(url, params=None, save_file=None, force_overwrite=False):
    """
    Scrape HTML data from a URL. If already scraped, don't re-query,
    read in from file instead of re-
    """
    # Store in the SAVE_PATH directory
    if save_file is not None and str(SAVE_PATH) not in save_file:
        save_file = str(SAVE_PATH / save_file)

    # If file already exists, simply read in
    if save_file is not None and Path(save_file).exists() and not force_overwrite:
        with open(save_file, 'r') as fhand:
            print("Read in", save_file)
            text = fhand.read()
            print(f"{len(text):,} characters")
            return text
    else:
        response = requests.get(url, params=params)
        print(f"Status code: {response.status_code} for URL {response.url}")
        print(f"{len(response.text):,} characters in {response.elapsed.seconds} seconds")
        if save_file is not None:
            with open(save_file, 'w') as fhand:
                fhand.write(response.text)
        return response

# %%
LSD_INDEX_SAVE = 'lsd_index_page.html'

# Will generate 'https://www.erowid.org/experiences/exp.cgi?S=2&C=1&Start=0&Max=1000'
payload = {'S': 2, 'C': 1, 'Start': 0, 'Max': 1000}
response = get_html(EXPERIENCE_INDEX_URL, params=payload,
                    save_file=LSD_INDEX_SAVE)
if isinstance(response, requests.models.Response):
    response = response.text
# Out:
# Read in artefacts/lsd_index_page.html
# 123,518 characters

# %% [markdown]
# Now we have scraped the HTML of the index of all LSD reviews, we have to do some HTML parsing to retrieve the hyperlinks to each review. We will use `beautifulsoup`.

# %%
from bs4 import BeautifulSoup, Tag, Comment, NavigableString

# %%
# soup = BeautifulSoup(html_doc, 'html.parser')
soup = BeautifulSoup(lsd_general_experiences_req, 'lxml')
print(soup.prettify()[:500])
# Out:
# <html>
#  <head>
#   <title>
#    LSD Reports - General : Erowid Experience Vaults
#   </title>
#   <meta content="Erowid Experience Vaults: An Experience" name="description"/>
#   <meta content="Experience Report Vaults, trip reports, stories, descriptions" name="keywords"/>
#   <link href="/includes/general_default.css" rel="stylesheet" type="text/css"/>
#   <link href="includes/exp.css" rel="stylesheet" type="text/css"/>
#   <!-- Sperowider <noindex/> -->
#  </head>
#  <body alink="#008080" bgcolor="#000000" link=

# %% [markdown]
# The index page is structured as a table like so:
#
# ![title](erowid_index.png)
#
# We will find all tables in the parse tree. Erowid's HTML is a little painfully set out. The obvious main table we want is actually the third table in the page, and is nested in the second table.

# %%
tables = soup.find_all('table')

# We want the third table (nested in the second)
index_table = tables[2]

# %%
for i, elem in enumerate(list(index_table.children)[:7]):
    print(f"{i + 1}. {type(elem)}: {elem}")
# Out:
# 1. <class 'bs4.element.NavigableString'>:
#
# 2. <class 'bs4.element.Tag'>: <tr height="10">
# <th width="75"><input onclick="SortBy('RA');" type="Button" value="Rating"/><img src="/experiences/images/arrow_down.jpg"/></th>
# <th width="230"><input onclick="SortBy('TA');" type="Button" value=" Title"/></th>
# <th width="105"><input onclick="SortBy('AA');" type="Button" value=" Author "/></th>
# <th width="150"><input onclick="SortBy('SA');" type="Button" value="Substance"/></th>
# <th width="85"><input onclick="SortBy('PDD');" type="Button" value="Pub Date"/><img src="/experiences/images/arrow_down.jpg"/></th>
# </tr>
# 3. <class 'bs4.element.NavigableString'>:
#
# 4. <class 'bs4.element.Tag'>: <tr height="8"><th colspan="5"></th></tr>
# 5. <class 'bs4.element.NavigableString'>:
#
# 6. <class 'bs4.element.Tag'>: <tr class=""><td> <img align="right" alt="Very Highly Recommended" border="0" src="images/exp_star_3.gif"/></td><td><a href="exp.php?ID=89042">Some Growing Up to Do</a></td><td>thingummajig</td><td>MDMA, LSD &amp; Cannabis</td><td align="right">Feb 2 2012</td>
# </tr>
# 7. <class 'bs4.element.NavigableString'>:

# %% [markdown]
# This is a bit annoying - every second child of the index tree is a blank `NavigableString`. This is the datatype `Beautifulsoup` uses to contain text within tags. I'm not sure whether the fault lies with `BeautifulSoup` for parsing the page weirdly, or Erowid for having weird HTML.
#
# In either case, to avoid dealing with this, we'll pull out all the table rows and just work with these.

# %%
for i, elem in enumerate(index_table.find_all('tr')):
    print(f"{i + 1}. {elem}: \n")
    if i >= 4:
        break
# Out:
# 1. <tr height="10">
# <th width="75"><input onclick="SortBy('RA');" type="Button" value="Rating"/><img src="/experiences/images/arrow_down.jpg"/></th>
# <th width="230"><input onclick="SortBy('TA');" type="Button" value=" Title"/></th>
# <th width="105"><input onclick="SortBy('AA');" type="Button" value=" Author "/></th>
# <th width="150"><input onclick="SortBy('SA');" type="Button" value="Substance"/></th>
# <th width="85"><input onclick="SortBy('PDD');" type="Button" value="Pub Date"/><img src="/experiences/images/arrow_down.jpg"/></th>
# </tr>:
#
# 2. <tr height="8"><th colspan="5"></th></tr>:
#
# 3. <tr class=""><td> <img align="right" alt="Very Highly Recommended" border="0" src="images/exp_star_3.gif"/></td><td><a href="exp.php?ID=89042">Some Growing Up to Do</a></td><td>thingummajig</td><td>MDMA, LSD &amp; Cannabis</td><td align="right">Feb 2 2012</td>
# </tr>:
#
# 4. <tr class=""><td> <img align="right" alt="Highly Recommended" border="0" src="images/exp_star_2.gif"/></td><td><a href="exp.php?ID=112505">My Minidose Manifesto</a></td><td>Uncle Iroh</td><td>LSD</td><td align="right">Oct 26 2018</td>
# </tr>:
#
# 5. <tr class=""><td> <img align="right" alt="Highly Recommended" border="0" src="images/exp_star_2.gif"/></td><td><a href="exp.php?ID=112152">The Colossus</a></td><td>nervewing</td><td>Memantine, 3-MEO-PCE, LSD, 4-AcO-MiPT, 4-HO-MET, 2C-C, Clonazepam &amp; Aripiprazole</td><td align="right">Aug 4 2018</td>
# </tr>:

# %% [markdown]
# The first row has the headers, the second row is blank, then the review links start from the third row. Note that each review row has:
# - an image indicating the rated number of stars
# - a link to the write-up with a title
# - a username
# - a list of substances used
# - a date
#
# We'll go through the table, extracting all these fields into a list of dict, then converting them into a `Pandas.DataFrame`.

# %%
# Get all rows of this table
rows = index_table.find_all('tr')

# %%
# First row is the headers - we will retrieve the header values
headers = rows[0].find_all('th')
headers
# Out:
# [<th width="75"><input onclick="SortBy('RA');" type="Button" value="Rating"/><img src="/experiences/images/arrow_down.jpg"/></th>,
#  <th width="230"><input onclick="SortBy('TA');" type="Button" value=" Title"/></th>,
#  <th width="105"><input onclick="SortBy('AA');" type="Button" value=" Author "/></th>,
#  <th width="150"><input onclick="SortBy('SA');" type="Button" value="Substance"/></th>,
#  <th width="85"><input onclick="SortBy('PDD');" type="Button" value="Pub Date"/><img src="/experiences/images/arrow_down.jpg"/></th>]

# %%
col_names = [th.input['value'].strip() for th in headers]
col_names
# Out:
# ['Rating', 'Title', 'Author', 'Substance', 'Pub Date']

# %%
experiences = []

# Reviews start from the 3rd row
for row in rows[2:]:
    entry = {}
    # Get all cells of the row
    for i, td in enumerate(row.find_all('td')):
        # The first column has an img tag of stars rating
        if td.find('img') is not None:
            entry[col_names[i]] = td.img['alt']
        # For all other rows, just want the text
        else:
            entry[col_names[i]] = td.text
        # If link included, add that to dict
        if td.find('a') is not None:
            entry['href'] = td.find('a').get('href')
    experiences.append(entry)

# %%
len(experiences)
# Out:
# 657

# %%
experiences[:3]
# Out:
# [{'Rating': 'Very Highly Recommended',
#   'Title': 'Some Growing Up to Do',
#   'href': 'exp.php?ID=89042',
#   'Author': 'thingummajig',
#   'Substance': 'MDMA, LSD & Cannabis',
#   'Pub Date': 'Feb 2 2012'},
#  {'Rating': 'Highly Recommended',
#   'Title': 'My Minidose Manifesto',
#   'href': 'exp.php?ID=112505',
#   'Author': 'Uncle Iroh',
#   'Substance': 'LSD',
#   'Pub Date': 'Oct 26 2018'},
#  {'Rating': 'Highly Recommended',
#   'Title': 'The Colossus',
#   'href': 'exp.php?ID=112152',
#   'Author': 'nervewing',
#   'Substance': 'Memantine, 3-MEO-PCE, LSD, 4-AcO-MiPT, 4-HO-MET, 2C-C, Clonazepam & Aripiprazole',
#   'Pub Date': 'Aug 4 2018'}]

# %% [markdown]
# Many reviews seem to include multiple drugs, e.g. the first review would appear to include memantine, 3-MEO-PCE and a bunch of things. We'll restrict to just the pure LSD reviews.

# %%
lsd_only = [ent for ent in experiences if ent['Substance'] == 'LSD']

# %%
len(lsd_only)
# Out:
# 438

# %% [markdown]
# Finally we can convert this to a `Pandas DataFrame` and save to file as a CSV.

# %%
df = pd.DataFrame(lsd_only)
df = df[['Rating', 'Title', 'href', 'Author', 'Substance', 'Pub Date']]
df.head()
# Out:
#                Rating                                    Title  \
# 0  Highly Recommended                    My Minidose Manifesto
# 1  Highly Recommended      Physics at the Edge of the Universe
# 2  Highly Recommended  Somatic Vision and Cosmic Consciousness
# 3  Highly Recommended                      LSD Microdosing RCT
# 4  Highly Recommended       It Can Be Whatever I Want It to Be
#
#                 href       Author Substance     Pub Date
# 0  exp.php?ID=112505   Uncle Iroh       LSD  Oct 26 2018
# 1   exp.php?ID=69866       Spooky       LSD  Apr 19 2016
# 2   exp.php?ID=77462    Lokapalas       LSD  Nov 28 2013
# 3  exp.php?ID=101638    Gwern.net       LSD  Oct 23 2013
# 4   exp.php?ID=88486  triptacular       LSD   Dec 4 2012

# %%
df['Pub Date'] = pd.to_datetime(df['Pub Date'])

# %%
df.head()
# Out:
#                Rating                                    Title  \
# 0  Highly Recommended                    My Minidose Manifesto
# 1  Highly Recommended      Physics at the Edge of the Universe
# 2  Highly Recommended  Somatic Vision and Cosmic Consciousness
# 3  Highly Recommended                      LSD Microdosing RCT
# 4  Highly Recommended       It Can Be Whatever I Want It to Be
#
#                 href       Author Substance   Pub Date
# 0  exp.php?ID=112505   Uncle Iroh       LSD 2018-10-26
# 1   exp.php?ID=69866       Spooky       LSD 2016-04-19
# 2   exp.php?ID=77462    Lokapalas       LSD 2013-11-28
# 3  exp.php?ID=101638    Gwern.net       LSD 2013-10-23
# 4   exp.php?ID=88486  triptacular       LSD 2012-12-04

# %%
csv_output_path = str(SAVE_PATH / 'lsd_metadata.csv')
df.to_csv(csv_output_path, index=None)

# %% [markdown]
# We will now set up a loop to iterate through and scrape the HTML for each experience write-up. We'll wait 1 second between queries to be very nice to their servers.
#
# Note that some reviews redirect to an external site. Because the next stage will depend on a predictably structured HTML tree, we'll check the scraped URL and discard any that redirected outside Erowid's domain. Hopefully this is not very common

# %%
import time

redirects = []

for i, row in df.iterrows():
    query_url = 'https://www.erowid.org/experiences_html/' + row['href']
    # Extract the number from e.g. "exp.php?ID=101638"
    fname = str(SAVE_PATH / 'experiences' / (query_url.split('ID=')[-1] + '.html'))
    experience_res = get_html(query_url)
    
    # Check for redirect
    if 'https://www.erowid.org' not in experience_res.url:
        redirects.append(experience_res.url)
    else:
        with open(fname, 'w') as fhand:
            fhand.write(experience.text)
    time.sleep(1)
# Out:
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=112505
# 18,218 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=69866
# 18,959 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=77462
# 42,875 characters in 0 seconds
# Status code: 200 for URL http://www.gwern.net/LSD%20microdosing
# 330 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=88486
# 28,678 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=76778
# 21,377 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=93659
# 14,451 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=83544
# 26,379 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=73418
# 15,155 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=69999
# 26,141 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=69386
# 15,793 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=52084
# 13,763 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=51368
# 24,561 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=39028
# 38,775 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=7528
# 13,611 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=17624
# 14,173 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=112422
# 21,206 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=112379
# 18,549 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=112070
# 27,134 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=88579
# 24,946 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=68891
# 18,935 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=111678
# 14,821 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=107228
# 39,636 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=106589
# 28,039 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=86012
# 25,008 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=99985
# 12,533 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=99779
# 36,706 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=68795
# 18,769 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=83671
# 32,440 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=89094
# 25,283 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=98027
# 25,985 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=90041
# 19,862 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=83138
# 18,303 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=69495
# 16,973 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=72025
# 13,693 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=96427
# 20,451 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=66912
# 21,459 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=66222
# 16,179 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=88121
# 24,780 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=88499
# 16,918 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=67788
# 21,725 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=67627
# 17,255 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=65797
# 22,465 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=80897
# 23,809 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=57959
# 14,924 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=72107
# 56,709 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=70035
# 18,691 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=48302
# 18,251 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=45498
# 10,765 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=45369
# 14,065 characters in 0 seconds
# Status code: 200 for URL https://www.macleans.ca/
# 146,695 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=62094
# 23,965 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=43207
# 21,523 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=33841
# 15,717 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=56890
# 37,800 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=35542
# 13,353 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=56905
# 21,633 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=23324
# 14,996 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=29225
# 21,147 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=52018
# 16,057 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=51241
# 28,857 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=48916
# 13,744 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=46848
# 17,321 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=46857
# 23,685 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=46841
# 20,592 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=18759
# 16,796 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=14224
# 10,908 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=34238
# 18,746 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=11370
# 13,281 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=10440
# 13,937 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=9980
# 12,382 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=27292
# 7,763 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=24938
# 21,242 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=26645
# 9,860 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=5566
# 17,747 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=2939
# 15,694 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=3174
# 12,536 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=3045
# 11,705 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=9633
# 13,575 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=5345
# 19,363 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=3690
# 8,057 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=1104
# 13,424 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=112543
# 21,649 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=70308
# 21,998 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=112405
# 29,839 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=111357
# 51,027 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=112021
# 15,959 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=111044
# 18,871 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=111973
# 16,265 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=72237
# 15,690 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=71403
# 13,198 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=46669
# 12,157 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=87819
# 18,416 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=97785
# 12,439 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=97314
# 39,796 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=68181
# 14,355 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=108860
# 44,078 characters in 3 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=111446
# 17,602 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=98798
# 20,465 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=56785
# 12,770 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=105578
# 17,405 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=68350
# 15,763 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=76425
# 15,763 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=108882
# 21,903 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=108184
# 13,148 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=77295
# 23,787 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=65647
# 17,721 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=96439
# 11,662 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=68377
# 10,971 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=72952
# 14,306 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=99562
# 20,610 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=98408
# 13,570 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=95433
# 12,074 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=76044
# 15,730 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=54727
# 9,938 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=55069
# 17,925 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=52623
# 12,078 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=51465
# 11,403 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=39624
# 15,275 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=37490
# 16,543 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=37241
# 17,756 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=46209
# 15,125 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=46208
# 12,063 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=62055
# 11,966 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=47362
# 12,720 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=58457
# 18,425 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=62593
# 13,823 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=41794
# 8,933 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=44321
# 17,937 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=49551
# 15,938 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=54017
# 21,642 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=29489
# 15,580 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=35186
# 13,952 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=30928
# 14,647 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=39249
# 12,186 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=31853
# 10,512 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=53036
# 16,652 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=44974
# 23,622 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=14549
# 15,394 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=13144
# 13,464 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=38273
# 12,191 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=10013
# 11,928 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=8757
# 14,982 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=19394
# 13,340 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=7708
# 12,967 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=22951
# 8,376 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=16655
# 10,539 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=15729
# 26,987 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=1389
# 16,419 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=72093
# 15,921 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=112738
# 12,608 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=85095
# 16,890 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=89144
# 15,871 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=74814
# 18,532 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=112437
# 21,268 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=65500
# 10,502 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=111135
# 36,549 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=88696
# 10,938 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=81980
# 11,924 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=112301
# 12,013 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=56804
# 12,202 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=111654
# 12,797 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=84714
# 23,423 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=111209
# 27,492 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=94307
# 17,739 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=108551
# 88,154 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=58615
# 11,634 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=48684
# 10,416 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=72573
# 13,215 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=109051
# 26,127 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=110263
# 10,040 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=111901
# 12,277 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=76812
# 19,126 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=110330
# 14,780 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=39412
# 9,436 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=32243
# 8,786 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=111775
# 21,821 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=111573
# 18,531 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=68131
# 15,674 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=76842
# 15,329 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=51309
# 13,422 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=24042
# 9,937 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=89907
# 17,211 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=74293
# 13,712 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=109574
# 18,991 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=111350
# 12,634 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=35197
# 11,636 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=76211
# 12,314 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=79443
# 12,184 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=51468
# 9,024 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=102026
# 18,931 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=110564
# 10,474 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=109669
# 12,939 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=88945
# 9,776 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=109320
# 13,940 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=64562
# 22,391 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=61081
# 12,812 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=74789
# 60,368 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=61840
# 10,178 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=45384
# 12,525 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=54130
# 17,309 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=44878
# 14,694 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=42715
# 11,978 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=71275
# 7,393 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=49021
# 9,389 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=66873
# 7,282 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=46978
# 12,524 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=10906
# 12,175 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=55244
# 11,489 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=35108
# 11,085 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=34097
# 13,434 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=10450
# 11,058 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=49943
# 11,992 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=44070
# 11,053 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=10318
# 12,581 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=50271
# 9,817 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=44746
# 11,274 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=10165
# 8,674 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=10143
# 13,857 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=9634
# 13,402 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=15436
# 16,446 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=9545
# 10,277 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=12882
# 7,882 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=39324
# 8,594 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=12069
# 15,825 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=9880
# 8,765 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=8865
# 22,388 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=32420
# 7,920 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=31407
# 9,450 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=28531
# 11,147 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=28471
# 10,576 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=18029
# 18,215 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=24193
# 15,275 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=26596
# 13,770 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=24991
# 10,827 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=24164
# 9,493 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=22648
# 8,981 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=20972
# 9,610 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=6896
# 19,439 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=6661
# 13,165 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=6486
# 17,051 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=6560
# 14,886 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=6288
# 12,097 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=5553
# 12,102 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=5420
# 12,687 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=4466
# 8,649 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=3108
# 8,470 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=2885
# 8,255 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=2765
# 10,974 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=10695
# 6,953 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=2647
# 9,741 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=3443
# 12,662 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=117
# 10,895 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=7273
# 9,423 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=1384
# 9,453 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=1382
# 16,813 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=4026
# 11,133 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=4388
# 7,831 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=4926
# 8,965 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=2690
# 10,092 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=2468
# 8,874 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=4600
# 9,550 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=1084
# 12,902 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=1057
# 8,651 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=3896
# 7,418 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=3677
# 14,311 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=1533
# 9,344 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=841
# 14,949 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=761
# 15,445 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=1312
# 19,137 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=714
# 8,597 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=472
# 9,098 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=661
# 11,864 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=2004
# 9,509 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=2001
# 9,262 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=1590
# 16,622 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=1996
# 22,091 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=1994
# 7,461 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=1991
# 7,976 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=1988
# 9,482 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=1987
# 18,312 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=1986
# 9,838 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=1985
# 18,473 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=1984
# 8,165 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=1983
# 16,444 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=1982
# 12,986 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=1981
# 9,286 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=8
# 15,178 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=80843
# 10,255 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=13450
# 11,321 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=110619
# 9,246 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=50818
# 12,509 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=38734
# 9,871 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=112660
# 8,523 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=21485
# 9,208 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=67651
# 11,483 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=91041
# 11,807 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=62393
# 17,270 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=32929
# 9,097 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=16365
# 10,667 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=75399
# 11,412 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=50355
# 15,063 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=76050
# 11,872 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=34149
# 9,003 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=53355
# 12,603 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=31034
# 9,776 characters in 2 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=72119
# 13,429 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=51693
# 11,388 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=60233
# 12,394 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=112086
# 10,619 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=65847
# 8,328 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=105058
# 144,433 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=111719
# 11,462 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=57582
# 10,111 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=52711
# 10,996 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=63774
# 11,158 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=111006
# 10,667 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=112000
# 12,640 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=43369
# 12,185 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=111846
# 13,266 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=108767
# 6,976 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=111114
# 9,586 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=52630
# 9,376 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=20389
# 7,113 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=111468
# 8,718 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=79486
# 21,697 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=111456
# 17,963 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=110817
# 10,420 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=39747
# 8,145 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=77218
# 12,752 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=89126
# 10,104 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=111641
# 7,240 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=70097
# 7,823 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=66686
# 9,808 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=51907
# 8,450 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=10726
# 12,295 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=54801
# 7,150 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=109688
# 10,911 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=45974
# 13,200 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=51225
# 9,242 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=72407
# 17,372 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=97458
# 9,915 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=109057
# 10,028 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=108662
# 10,576 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=110268
# 11,792 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=73122
# 13,568 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=88733
# 15,454 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=68313
# 11,993 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=93816
# 15,688 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=69278
# 12,530 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=66475
# 35,947 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=10093
# 10,797 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=17422
# 14,859 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=12658
# 10,741 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=30683
# 10,782 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=18486
# 10,396 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=25019
# 13,357 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=24375
# 17,732 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=7264
# 9,096 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=6506
# 10,374 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=5673
# 8,575 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=5239
# 10,155 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=5223
# 8,587 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=5307
# 12,427 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=1534
# 10,399 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=14114
# 12,330 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=96678
# 36,409 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=18675
# 7,655 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=56014
# 10,710 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=58147
# 8,741 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=111432
# 12,090 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=109738
# 9,811 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=60225
# 8,731 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=57443
# 7,908 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=61751
# 8,429 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=84118
# 8,035 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=28090
# 7,869 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=45733
# 7,840 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=53556
# 9,480 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=55318
# 7,644 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=34622
# 7,868 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=112075
# 10,255 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=17220
# 9,587 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=70183
# 7,601 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=49782
# 7,483 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=54676
# 7,639 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=77279
# 7,537 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=43438
# 8,764 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=111748
# 9,752 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=111814
# 11,827 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=110119
# 8,054 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=110205
# 8,378 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=67800
# 8,160 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=34640
# 8,228 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=100793
# 7,578 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=111711
# 7,492 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=66200
# 8,258 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=41899
# 8,451 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=81725
# 7,269 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=71722
# 7,505 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=66136
# 10,920 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=51769
# 7,344 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=31704
# 7,806 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=15651
# 8,999 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=87566
# 7,517 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=55337
# 8,569 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=29920
# 8,034 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=66582
# 7,851 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=111129
# 15,622 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=111037
# 10,472 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=107444
# 9,295 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=55418
# 9,543 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=55427
# 10,915 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=51962
# 6,432 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=33561
# 7,500 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=27875
# 9,719 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=20945
# 10,296 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=7260
# 10,910 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=3312
# 10,103 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=326
# 17,160 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=9698
# 9,353 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=127
# 10,219 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=5331
# 6,578 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=4181
# 8,120 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=2756
# 8,320 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=867
# 18,195 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=3665
# 7,522 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=3772
# 9,381 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=2355
# 8,500 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=985
# 9,593 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=3505
# 7,849 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=3394
# 10,058 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=675
# 7,933 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=672
# 11,886 characters in 1 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=2516
# 10,038 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=502
# 18,851 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=1152
# 9,908 characters in 0 seconds
# Status code: 200 for URL https://www.erowid.org/experiences/exp.php?ID=395
# 15,491 characters in 1 seconds

# %%
3 + 5
# Out:
# 8
